# %% [markdown]
# # Working with data
# Data is one of the most important resources of the digital age. You and everyone around you creates an astounding amount of data each day.
#
# Machine learning makes sense of this data through the help of machine learning models.

# %% [markdown]
# ## Test and training data.
# For all supervised learning task you need to separate your data into test and training data.
# This can be done using the excellent pandas library.

# %%
# Pandas
#Pandas is a library for working with data in python
#http://pandas.pydata.org/

## Importing pandas

import pandas as pd

Is usually how to import pandas to a project.

When we are working with machine learning we commonly use CSV files.
testdata = pd.read_csv("test.csv")

# %%
# how to import pandas to a project
import pandas as pd

# %% [markdown]
# When we are working with machine learning we commonly use CSV files.
# A CSV file is a comma separated file for storing values.

# %%
# load a csv file into a pandas dataframe
testdata = pd.read_csv("https://www.floydhub.com/viewer/data/res7UHjG5WSPgPStBT84xW/ID-OXY-1.csv")

# %%
# a loaded csv file gets stored in a pandas dataframe

# get the first and last values from a pandas dataframe
testdata.head

# get the first data from the first 10 rows of a pandas dataframe
testdata[0: 10]
# Out:
#         CH1       CH2       CH3       CH4       CH5       CH6       CH7  \
# 0  0.070226  0.048859 -0.016975 -0.037979 -0.033404 -0.018375 -0.035583
# 1  0.071212  0.049507 -0.016702 -0.038571 -0.033259 -0.015925 -0.034457
# 2  0.072090  0.050068 -0.016485 -0.039217 -0.033184 -0.013765 -0.033564
# 3  0.072890  0.050565 -0.016324 -0.039911 -0.033176 -0.011883 -0.032882
# 4  0.073640  0.051022 -0.016216 -0.040647 -0.033227 -0.010262 -0.032391
# 5  0.074364  0.051456 -0.016159 -0.041415 -0.033328 -0.008879 -0.032062
# 6  0.075081  0.051883 -0.016147 -0.042206 -0.033465 -0.007704 -0.031871
# 7  0.075806  0.052311 -0.016175 -0.043007 -0.033622 -0.006705 -0.031792
# 8  0.076551  0.052744 -0.016241 -0.043812 -0.033784 -0.005852 -0.031803
# 9  0.077320  0.053183 -0.016341 -0.044614 -0.033940 -0.005115 -0.031888
#
#         CH8       CH9      CH10  ...       LEARNINGDISORDER  \
# 0  0.015692 -0.002534 -0.059817  ...   NO-LEARNING-DISORDER
# 1  0.017883  0.000648 -0.057141  ...   NO-LEARNING-DISORDER
# 2  0.019843  0.003697 -0.054676  ...   NO-LEARNING-DISORDER
# 3  0.021573  0.006617 -0.052415  ...   NO-LEARNING-DISORDER
# 4  0.023083  0.009407 -0.050347  ...   NO-LEARNING-DISORDER
# 5  0.024387  0.012068 -0.048455  ...   NO-LEARNING-DISORDER
# 6  0.025509  0.014600 -0.046718  ...   NO-LEARNING-DISORDER
# 7  0.026473  0.017003 -0.045113  ...   NO-LEARNING-DISORDER
# 8  0.027304  0.019275 -0.043620  ...   NO-LEARNING-DISORDER
# 9  0.028031  0.021418 -0.042220  ...   NO-LEARNING-DISORDER
#
#        HEARINGPROBLEM      HEADINJURY     PSYCHIATRIC     LEARNINGDISORDER.1  \
# 0  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 1  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 2  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 3  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 4  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 5  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 6  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 7  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 8  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
# 9  NO-HEARING-PROBLEM  NO-HEAD-INJURY  NO-PSYCHIATRIC  NO-LEARNING-DISORDERS
#
#       SEIZURES     AUTISM  ETHNICITY     MAJOR  YEAR
# 0  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 1  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 2  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 3  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 4  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 5  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 6  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 7  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 8  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
# 9  NO-SEIZURES  NO-AUTISM   HISPANIC  POLITICS  2014
#
# [10 rows x 69 columns]

# %% [markdown]
# # Numpy
# Numpy is a library for performing math in Python. For the system

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.layers import Dropout
from keras.optimizers import RMSprop
from keras import optimizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy
import keras

# Remove warnings
#import warnings
#warnings.filterwarnings('ignore')

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

dataset = pd.read_csv("https://www.floydhub.com/viewer/data/res7UHjG5WSPgPStBT84xW/ID-OXY-1.csv")
# split into input (X) and output 󰀀 variables

# Remove missing values
dataset = dataset.dropna()

# make a label dataset
dataset["Label"] = dataset["Mark"]

# change rest values to
dataset["Mark"][dataset["Mark"] == "REST"] = 0
dataset["Mark"][dataset["Mark"] == "ADDITION"] = 1
dataset["Mark"][dataset["Mark"] == "PASSTHOUGHT"] = 2
dataset["Mark"][dataset["Mark"] == "JUNK"] = 3

# remove the JUNK data
dataset = dataset[dataset.Mark != 2]
dataset = dataset[dataset.Mark != 3]

# shuffle the data
dataset = dataset.sample(frac=1)

X = np.array(dataset.ix[:, :'CH52'])
Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.Mark])

# Dropout - the number of neurons removed at each layers, who are readded when testing
# Batch size - the number of data points added at each time, affects training time
# Epochs - the number of training/test sessions

# create model
model = Sequential()
model.add(BatchNormalization(input_shape=(52,)))
model.add(Dropout(0.1))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))

model.add(Dense(2, kernel_initializer='uniform', activation='softmax'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# Fit the model
history = model.fit(X, Y, validation_split=0.5, epochs=250, batch_size=25, verbose=0)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# /Users/birgermoell/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/birgermoell/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/birgermoell/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/birgermoell/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
